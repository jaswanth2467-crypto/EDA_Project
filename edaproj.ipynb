# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("C:\ML\sales.csv")
print("First 5 Rows:")
print(df.head())
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\M'
# <>:3: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\heman\AppData\Local\Temp\ipykernel_26168\778030246.py:3: SyntaxWarning: invalid escape sequence '\M'
#   df = pd.read_csv("C:\ML\sales.csv")
# First 5 Rows:
#    Sales  Profit  Quantity         Category
# 0    500      50         2       Technology
# 1    700     100         3        Furniture
# 2    300      20         1  Office Supplies
# 3    900     150         4       Technology
# 4    450      40         2        Furniture

# %%
print("\nSummary Statistics:")
print(df.describe())
# Out:
# Summary Statistics:
#             Sales      Profit   Quantity
# count   10.000000   10.000000  10.000000
# mean   575.000000   75.000000   2.700000
# std    205.818151   47.492689   1.337494
# min    300.000000   20.000000   1.000000
# 25%    412.500000   36.250000   2.000000
# 50%    550.000000   65.000000   2.500000
# 75%    737.500000  115.000000   3.750000
# max    900.000000  150.000000   5.000000

# %%
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# Sales       0
# Profit      0
# Quantity    0
# Category    0
# dtype: int64

# %%
df["Sales"].hist()
plt.title("Sales Distribution")
plt.xlabel("Sales")
plt.ylabel("Frequency")
plt.show()

# %%
df.plot.scatter(x="Sales", y="Profit")
plt.title("Sales vs Profit")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("data.csv")

print("First 5 Rows:")
print(df.head())

print("\nSummary Statistics:")
print(df.describe())

print("\nMissing Values:")
print(df.isnull().sum())

df["Sales"].hist()
plt.title("Sales Distribution")
plt.xlabel("Sales")
plt.ylabel("Frequency")
plt.show()

df.plot.scatter(x="Sales", y="Profit")
plt.title("Sales vs Profit")
plt.show()

category_sales = df.groupby("Category")["Sales"].sum()
category_sales.plot(kind="bar")
plt.title("Category-wise Sales")
plt.ylabel("Total Sales")
plt.show()
